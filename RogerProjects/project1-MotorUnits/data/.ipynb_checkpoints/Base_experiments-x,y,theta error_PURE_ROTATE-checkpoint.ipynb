# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('base_PURE_ROTATE__K30_00000_B14_00000_rot_K20_00000_B5_50000.txt', sep=',')
# df2 = pd.read_csv('eye_K1_00000_B0_00800.txt', sep=',')
# df3 = pd.read_csv('eye_K1_00000_B0_17900.txt', sep=',')

# %%
df1
# Out:
#        time   x_error   y_error  theta_error
# 0     0.000 -0.000000 -0.000000     0.000001
# 1     0.001  0.000000 -0.000000     0.000001
# 2     0.002  0.000000 -0.000000     0.000002
# 3     0.003  0.000000 -0.000000     0.000003
# 4     0.004  0.000000 -0.000000     0.000004
# 5     0.005  0.000000 -0.000000     0.000005
# 6     0.006  0.000000 -0.000000     0.000006
# 7     0.007  0.000000 -0.000000     0.000007
# 8     0.008  0.000000 -0.000000     0.000008
# 9     0.009  0.000000 -0.000000     0.000009
# 10    0.010  0.000000 -0.000000     0.000010
# 11    0.011  0.000000 -0.000000     0.000011
# 12    0.012  0.000000 -0.000000     0.000012
# 13    0.013  0.000000 -0.000000     0.000013
# 14    0.014  0.000000 -0.000000     0.000014
# 15    0.015  0.000000 -0.000000     0.000015
# 16    0.016  0.000000 -0.000001     0.000016
# 17    0.017  0.000000 -0.000001     0.000016
# 18    0.018  0.000000 -0.000001     0.000017
# 19    0.019  0.000000 -0.000001     0.000018
# 20    0.020  0.000000 -0.000001     0.000019
# 21    0.021  0.000000 -0.000001     0.000019
# 22    0.022  0.000000 -0.000001     0.000020
# 23    0.023  0.000000 -0.000001     0.000021
# 24    0.024  0.000000 -0.000001     0.000021
# 25    0.025  0.000000 -0.000001     0.000022
# 26    0.026  0.000000 -0.000001     0.000022
# 27    0.027  0.000000 -0.000001     0.000023
# 28    0.028  0.000000 -0.000001     0.000024
# 29    0.029  0.000000 -0.000001     0.000024
# ...     ...       ...       ...          ...
# 3426  3.426  2.151566  0.065979     0.000000
# 3427  3.427  2.151974  0.065979     0.000000
# 3428  3.428  2.152382  0.065979     0.000000
# 3429  3.429  2.152790  0.065979     0.000000
# 3430  3.430  2.153199  0.065979     0.000000
# 3431  3.431  2.153607  0.065979     0.000000
# 3432  3.432  2.154015  0.065979     0.000000
# 3433  3.433  2.154423  0.065979     0.000000
# 3434  3.434  2.154832  0.065979     0.000000
# 3435  3.435  2.155240  0.065979     0.000000
# 3436  3.436  2.155648  0.065979     0.000000
# 3437  3.437  2.156056  0.065979     0.000000
# 3438  3.438  2.156464  0.065979     0.000000
# 3439  3.439  2.156873  0.065979     0.000000
# 3440  3.440  2.157281  0.065979     0.000000
# 3441  3.441  2.157689  0.065979     0.000000
# 3442  3.442  2.158097  0.065979     0.000000
# 3443  3.443  2.158505  0.065979     0.000000
# 3444  3.444  2.158914  0.065979     0.000000
# 3445  3.445  2.159322  0.065979     0.000000
# 3446  3.446  2.159730  0.065979     0.000000
# 3447  3.447  2.160138  0.065979     0.000000
# 3448  3.448  2.160546  0.065979     0.000000
# 3449  3.449  2.160955  0.065979     0.000000
# 3450  3.450  2.161363  0.065979     0.000000
# 3451  3.451  2.161771  0.065979     0.000000
# 3452  3.452  2.162179  0.065979     0.000000
# 3453  3.453  2.162587  0.065979     0.000000
# 3454  3.454  2.162996  0.065979     0.000000
# 3455  3.455  2.163404  0.065979     0.000000
#
# [3456 rows x 4 columns]

# %%
df1.shape
# Out:
# (3456, 4)

# %%
params = {'legend.fontsize': 20,
          'legend.handlelength': 2}
plt.rcParams.update(params)

# %%
plt.figure(1, figsize=(16, 8))
# plt.plot(df1['time'], df1['y_error'],
#          linestyle=':', color='blue')
plt.scatter(df1['time'], df1['x_error'], s=1, label='x error (in the x^B direction of Roger)')
# plt.xlim([1.26,1.38])
# plt.ylim([-0.5,0.5])
plt.title('*** Pure $\pi$/2 rotation about $\hat{z}_{B}$ axis ***\n\
Target = (0.970, 0.000, 0.000)', fontsize=25)
plt.xlabel('Time', fontsize=25)
plt.ylabel('Error', fontsize=25)
plt.axhline(y=0.0, color='y', linestyle=':')
plt.legend()

# %%
plt.figure(1, figsize=(16, 8))
# plt.plot(df1['time'], df1['y_error'],
#          linestyle=':', color='blue')
plt.scatter(df1['time'], df1['y_error'], s=1, label='y error (in the y^B direction of Roger)')
# plt.xlim([1.26,1.38])
plt.ylim([-0.4,0.3])
plt.title('*** Pure $\pi$/2 rotation about $\hat{z}_{B}$ axis ***\n\
Target = (0.970, 0.000, 0.000)', fontsize=25)
plt.xlabel('Time', fontsize=25)
plt.ylabel('Error', fontsize=25)
plt.axhline(y=0.0, color='y', linestyle=':')
plt.legend()

# %%
plt.figure(1, figsize=(16, 8))
# plt.plot(df1['time'], df1['y_error'],
#          linestyle=':', color='blue')
plt.scatter(df1['time'], df1['theta_error'], s=1, label='Theta error')
# plt.xlim([1.26,1.38])
# plt.ylim([-0.03, 0.03])
plt.title('*** Pure $\pi$/2 rotation about $\hat{z}_{B}$ axis ***\n\
Target = (0.970, 0.000, 0.000)', fontsize=25)
plt.xlabel('Time', fontsize=25)
plt.ylabel('Error', fontsize=25)
plt.axhline(y=0.0, color='y', linestyle=':')
plt.legend()
