# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
df1 = pd.read_csv('eye_K1_50000_B0_02191.txt')

# %%
df1
# Out:
#        time   theta__error   theta_dot_error
# 0     0.000      -1.500001         -0.000390
# 1     0.001      -1.478840         14.106615
# 2     0.002      -1.446786         26.071670
# 3     0.003      -1.405691         36.087194
# 4     0.004      -1.357228         44.337913
# 5     0.005      -1.302898         50.999517
# 6     0.006      -1.244041         56.237653
# 7     0.007      -1.181849         60.207305
# 8     0.008      -1.117374         63.052553
# 9     0.009      -1.051540         64.906675
# 10    0.010      -0.985155         65.892482
# 11    0.011      -0.918917         66.122840
# 12    0.012      -0.853426         65.701255
# 13    0.013      -0.789193         64.722490
# 14    0.014      -0.726645         63.273141
# 15    0.015      -0.666133         61.432160
# 16    0.016      -0.607942         59.271307
# 17    0.017      -0.552294         56.855550
# 18    0.018      -0.499357         54.243412
# 19    0.019      -0.449248         51.487301
# ...

# %%
time = df1['time']

# %%
time
# Out:
# 0       0.000
# 1       0.001
# 2       0.002
# 3       0.003
# 4       0.004
# 5       0.005
# 6       0.006
# 7       0.007
# 8       0.008
# 9       0.009
# 10      0.010
# 11      0.011
# 12      0.012
# 13      0.013
# 14      0.014
# 15      0.015
# 16      0.016
# 17      0.017
# 18      0.018
# 19      0.019
# 20      0.020
# 21      0.021
# 22      0.022
# 23      0.023
# 24      0.024
# 25      0.025
# 26      0.026
# 27      0.027
# 28      0.028
# 29      0.029
#         ...
# 2835    2.835
# 2836    2.836
# 2837    2.837
# 2838    2.838
# 2839    2.839
# 2840    2.840
# 2841    2.841
# 2842    2.842
# 2843    2.843
# 2844    2.844
# 2845    2.845
# 2846    2.846
# 2847    2.847
# 2848    2.848
# 2849    2.849
# 2850    2.850
# 2851    2.851
# 2852    2.852
# 2853    2.853
# 2854    2.854
# 2855    2.855
# 2856    2.856
# 2857    2.857
# 2858    2.858
# 2859    2.859
# 2860    2.860
# 2861    2.861
# 2862    2.862
# 2863    2.863
# 2864    2.864
# ...

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.pi/2
# Out:
# 1.5707963267948966

# %%
x = 0.1

# %%
(-20)*math.pi*x*math.exp(-40*x) - (math.pi/2)*(math.exp(-40*x)) + math.pi/2
# Out:
# 1.4269456353482695

# %%
eq = (-20)*math.pi*x*math.exp(-40*x) - (math.pi/2)*(math.exp(-40*x)) + math.pi/2

# %%
df1.head()
# Out:
#     time   theta__error   theta_dot_error
# 0  0.000      -1.500001         -0.000390
# 1  0.001      -1.478840         14.106615
# 2  0.002      -1.446786         26.071670
# 3  0.003      -1.405691         36.087194
# 4  0.004      -1.357228         44.337913

# %%
def equation(x):
    return (-20)*math.pi*x*math.exp(-40*x) - (math.pi/2)*(math.exp(-40*x)) + math.pi/2

# %%
df1['analysis'] = df1['time'].apply(equation)

# %%
df1.head()
# Out:
#     time   theta__error   theta_dot_error  analysis
# 0  0.000      -1.500001         -0.000390  0.000000
# 1  0.001      -1.478840         14.106615  0.001224
# 2  0.002      -1.446786         26.071670  0.004766
# 3  0.003      -1.405691         36.087194  0.010444
# 4  0.004      -1.357228         44.337913  0.018085

# %%
time.apply(equation).head()
# Out:
# 0    0.000000
# 1    0.001224
# 2    0.004766
# 3    0.010444
# 4    0.018085
# Name: time, dtype: float64

# %%
plt.plot(df1['time'], df1['analysis'])
plt.axis([-0.2, 0.5, -0.2, 1.8])
plt.rcParams["figure.figsize"] = 30,20

# %%
df1 = pd.read_csv('arm_K80_00000_B10_00000.txt', sep=',')
# df2 = pd.read_csv('eye_K0_50000_B0_01265.txt', sep=',')
# df3 = pd.read_csv('eye_K1_50000_B0_02191.txt', sep=',')
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-3-f4970c015da4> in <module>
# ----> 1 df1 = pd.read_csv('arm_K80_00000_B10_00000.txt', sep=',')
#       2 # df2 = pd.read_csv('eye_K0_50000_B0_01265.txt', sep=',')
#       3 # df3 = pd.read_csv('eye_K1_50000_B0_02191.txt', sep=',')
#
# ...

# %%
plt.figure()
# plt.plot(df['time'], df[' theta__error'], df['time'], df[' theta_dot_error'])
# plt.plot(df1['time'], df1[' theta__error'], 'r--',
#          df2['time'], df2[' theta__error'], 'g--', 
#         df3['time'], df3[' theta__error'], 'b--')
plt.plot(df1['time'], df1['t_er_arm1'], 'r--')
plt.title('K=1.0 B=0.0179')
plt.xlabel('time)')
plt.ylabel('theta_error')
plt.axis([1.5, 3, -1.8, 0.5])
# plt.figure(figsize=(1,1))
plt.rcParams["figure.figsize"] = 30,20
# plt.rcParams.update({'font.size': 30})
plt.show()

# %%
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
import matplotlib.pyplot as plt

host = host_subplot(111, axes_class=AA.Axes)
# plt.subplots_adjust(right=0.75)
plt.rcParams["figure.figsize"] = 15,8

par1 = host.twinx()
par2 = host.twinx()

# offset = 60
# new_fixed_axis = par2.get_grid_helper().new_fixed_axis
# par2.axis["right"] = new_fixed_axis(loc="right",
#                                     axes=par2,
#                                     offset=(offset, 0))

# par2.axis["right"].toggle(all=True)

# host.set_xlim(1, 1.2)
host.set_xlim(1, 1.2)
host.set_ylim(-0.2, 1.8)

host.set_xlabel("Time")
host.set_ylabel("Theta_Error")
# par1.set_ylabel("Temperature")
# par2.set_ylabel("Velocity")

p1, = host.plot(df1['time'], df1[' theta__error'], 'r--', label="K=1.00000 B=0.01789")
p2, = par1.plot(df2['time'], df2[' theta__error'], 'g--', label="K=0.50000 B=0.01265")
p3, = par2.plot(df3['time'], df3[' theta__error'], 'b--', label="K=1.50000 B=0.02191")

par1.set_ylim(-0.2, 1.8)
par2.set_ylim(-0.2, 1.8)

plt.title('Finding K and B')
host.legend()

# host.axis["left"].label.set_color(p1.get_color())
# par1.axis["right"].label.set_color(p2.get_color())
# par2.axis["right"].label.set_color(p3.get_color())

plt.draw()
plt.show()
