# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
params = {'legend.fontsize': 20,
          'legend.handlelength': 2}
plt.rcParams.update(params)

# %%
# ARM
# K=30 B=6.5
df1 = pd.read_csv('CartesianError_FullyForwardStraight_K30_00000_B6_50000.txt', sep=',')
# df1.head(30)

# %%
plt.figure(1, figsize=(16, 8))
plt.plot(df1['time'], df1['arm_x_y_error'],
         linestyle=':', label='Left Arm Error')
# plt.plot(df1['time'], df1['eye_theta_error_r'],
#          linestyle=':', label='Right Eye')
# plt.scatter(df1['time'], df1['eye_theta_error_l'], s=0.2, label='Left Eye')
# plt.scatter(df1['time'], df1['eye_theta_error_r'], s=0.2, label='Right Eye')
# plt.xlim([0.3,6.1])
# plt.ylim([-0.2,0.2])
plt.title('Cartesian Error for Arm\n\
Stretching the Arm fully forward\n\
K=30, B=6.5', fontsize=25)
plt.xlabel('Time', fontsize=25)
plt.ylabel('Error', fontsize=25)
plt.axhline(y=0.0, color='y', linestyle=':')
plt.legend()
# plt.savefig('vis_bounce_3_0.33.png')

# %%
# ARM
# K=30 B=6.5
df2 = pd.read_csv('CartesianError_FullLeftToFullRight_K30_00000_B6_50000.txt', sep=',')
# df1.head(30)

# %%
plt.figure(2, figsize=(16, 8))
plt.plot(df2['time'], df2['arm_x_y_error'],
         linestyle=':', label='Left Arm Error')
# plt.plot(df1['time'], df1['eye_theta_error_r'],
#          linestyle=':', label='Right Eye')
# plt.scatter(df1['time'], df1['eye_theta_error_l'], s=0.2, label='Left Eye')
# plt.scatter(df1['time'], df1['eye_theta_error_r'], s=0.2, label='Right Eye')
# plt.xlim([0.3,6.1])
# plt.ylim([-0.2,0.2])
plt.title('Cartesian Error for Arm\n\
Full Left to Full Right\n\
K=30, B=6.5', fontsize=25)
plt.xlabel('Time', fontsize=25)
plt.ylabel('Error', fontsize=25)
plt.axhline(y=0.0, color='y', linestyle=':')
plt.legend()
# plt.savefig('vis_bounce_3_0.33.png')

# %%
# ARM
# K=30 B=6.5
df3 = pd.read_csv('CartesianError_FullyForwardToFullyBehind_K30_00000_B6_50000.txt', sep=',')
# df1.head(30)

# %%
plt.figure(3, figsize=(16, 8))
plt.plot(df3['time'], df3['arm_x_y_error'],
         linestyle=':', label='Left Arm Error')
# plt.plot(df1['time'], df1['eye_theta_error_r'],
#          linestyle=':', label='Right Eye')
# plt.scatter(df1['time'], df1['eye_theta_error_l'], s=0.2, label='Left Eye')
# plt.scatter(df1['time'], df1['eye_theta_error_r'], s=0.2, label='Right Eye')
# plt.xlim([0.3,6.1])
# plt.ylim([-0.2,0.2])
plt.title('Cartesian Error for Arm\n\
Full Forward to Full Behind\n\
K=30, B=6.5', fontsize=25)
plt.xlabel('Time', fontsize=25)
plt.ylabel('Error', fontsize=25)
plt.axhline(y=0.0, color='y', linestyle=':')
plt.legend()
# plt.savefig('vis_bounce_3_0.33.png')
