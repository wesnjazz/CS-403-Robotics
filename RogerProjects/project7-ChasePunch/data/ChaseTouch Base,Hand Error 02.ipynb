# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
params = {'legend.fontsize': 20,
          'legend.handlelength': 2}
plt.rcParams.update(params)

# %%
df1 = pd.read_csv('P7_02.txt', sep=',')

# %%
df1.tail()
# Out:
#        time  base_heading  distance_ball_base  distance_ball_hand
# 2473  2.473          0.83              0.3640              0.1975
# 2474  2.474          0.83              0.3641              0.1977
# 2475  2.475          0.83              0.3641              0.1978
# 2476  2.476          0.83              0.3642              0.1979
# 2477  2.477           NaN                 NaN                 NaN

# %%
plt.figure(1, figsize=(16, 8))
plt.plot(df1['time'], df1['base_heading'],
         linestyle=':', label='Base heading', color='green')
plt.plot(df1['time'], df1['distance_ball_base'],
         linestyle=':', label='distance Ball-Base', color='red')
plt.plot(df1['time'], df1['distance_ball_hand'],
         linestyle=':', label='distance Ball-Hand', color='blue')
# plt.scatter(df1['time'], df1['base_err'], s=0.2, label='Base Error')
# plt.scatter(df1['time'], df1['eye_theta_error_r'], s=0.2, label='Right Eye')
# plt.xlim([0.3,6.1])
# plt.ylim([-1.0,2.0])
plt.title('Ball is located at 0.83 (rad) in world frame', fontsize=25)
plt.xlabel('Time', fontsize=25)
plt.ylabel('Error', fontsize=25)
plt.axhline(y=0.0, color='y', linestyle=':')
plt.legend()
# plt.savefig('P401.png')

# %%
plt.figure(1, figsize=(16, 8))
plt.plot(df1['time'], df1['base_heading'],
         linestyle=':', label='Base heading', color='green')
plt.plot(df1['time'], df1['distance_ball_base'],
         linestyle=':', label='distance Ball-Base', color='red')
plt.plot(df1['time'], df1['distance_ball_hand'],
         linestyle=':', label='distance Ball-Hand', color='blue')
# plt.scatter(df1['time'], df1['base_err'], s=0.2, label='Base Error')
# plt.scatter(df1['time'], df1['eye_theta_error_r'], s=0.2, label='Right Eye')
plt.xlim([0.58,2.5])
plt.ylim([-0.1,2.0])
plt.title('Ball is located at 0.83 (rad) in world frame', fontsize=25)
plt.xlabel('Time', fontsize=25)
plt.ylabel('Error', fontsize=25)
plt.axhline(y=0.0, color='y', linestyle=':')
plt.legend()
# plt.savefig('P401.png')
