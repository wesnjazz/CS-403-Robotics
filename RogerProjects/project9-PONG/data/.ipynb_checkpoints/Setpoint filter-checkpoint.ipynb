# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
params = {'legend.fontsize': 20,
          'legend.handlelength': 2}
plt.rcParams.update(params)

# %%
df1 = pd.read_csv('P9_setpoint_on_X.txt', sep=',')

# %%
df1.head()
# Out:
#     time  base_heading  base_posX  base_posY  ball_posX  ball_posY
# 0  0.000        2.2089    -3.0000        0.0     0.0000     0.0000
# 1  0.001        0.2633    -3.0000       -0.0     3.8417     1.8441
# 2  0.002        0.2606    -2.9999        0.0     2.1045     1.3611
# 3  0.003        0.2594    -2.9995        0.0     2.0711     1.3455
# 4  0.004        0.2631    -2.9989        0.0     2.0274     1.3537

# %%
plt.figure(1, figsize=(16, 8))
plt.plot(df1['time'], df1['base_heading'],
         linestyle=':', label='Base heading')
plt.plot(df1['time'], df1['base_posX'],
         linestyle=':', label='Base position X')
plt.plot(df1['time'], df1['base_posY'],
         linestyle=':', label='Base position Y')
plt.plot(df1['time'], df1['ball_posX'],
         linestyle=':', label='Ball position X')
plt.plot(df1['time'], df1['ball_posY'],
         linestyle=':', label='Ball position Y')

# plt.scatter(df1['time'], df1['base_err'], s=0.2, label='Base Error')
# plt.scatter(df1['time'], df1['eye_theta_error_r'], s=0.2, label='Right Eye')
# plt.xlim([0.3,6.1])
# plt.ylim([-1.0,2.0])
plt.title('*** setpoint_filter(.) ***', fontsize=25)
plt.xlabel('Time', fontsize=25)
plt.ylabel('x/y/theta', fontsize=25)
plt.axhline(y=0.0, color='y', linestyle=':')
plt.legend()
# plt.savefig('P401.png')

# %%
plt.figure(1, figsize=(16, 8))
plt.plot(df1['time'], df1['base_heading'],
         linestyle=':', label='Base heading')
plt.plot(df1['time'], df1['distance_ball_base'],
         linestyle=':', label='distance Ball-Base')
plt.plot(df1['time'], df1['distance_ball_hand'],
         linestyle=':', label='distance Ball-Hand')
# plt.scatter(df1['time'], df1['base_err'], s=0.2, label='Base Error')
# plt.scatter(df1['time'], df1['eye_theta_error_r'], s=0.2, label='Right Eye')
plt.xlim([1.3,3.5])
plt.ylim([-0.1,2.0])
plt.title('*** ChaseTouch(.) ***', fontsize=25)
plt.xlabel('Time', fontsize=25)
plt.ylabel('Base Error', fontsize=25)
plt.axhline(y=0.0, color='y', linestyle=':')
plt.legend()
# plt.savefig('P401.png')
